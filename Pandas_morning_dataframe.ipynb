# %%
import numpy as np

# %%
import pandas as pd

# %%
dictt= {
    "name": ["vimal","om","priyanka"],
    "class": [12,7,10],
    "marks":[90,60,62],
    "age":[22,20,21]
}

# %%
df= pd.DataFrame(dictt)
df
# Out:
#        name  class  marks  age
# 0     vimal     12     90   22
# 1        om      7     60   20
# 2  priyanka     10     62   21

# %%
df.size
# Out:
# 12

# %%
df.columns
# Out:
# Index(['name', 'class', 'marks', 'age'], dtype='object')

# %%
df.values
# Out:
# array([['vimal', 12, 90, 22],
#        ['om', 7, 60, 20],
#        ['priyanka', 10, 62, 21]], dtype=object)

# %%
df.rename(columns= {"name":"nameee"},inplace=True)

# %%
df
# Out:
#      nameee  class  marks  age
# 0     vimal     12     90   22
# 1        om      7     60   20
# 2  priyanka     10     62   21

# %%
X=pd.read_csv("movies.csv")
X
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
X.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
X.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
X.values
# Out:
# array([['Uri: The Surgical Strike', 'tt8291224',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#         ...,
#         'Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Gautam|Kirti Kulhari|Rajit Kapoor|Ivan Rodrigues|Manasi Parekh|Swaroop Sampat|Riva Arora|Yogesh Soman|Fareed Ahmed|Akashdeep Arora|Kallol Banerjee|',
#         '4 wins', '11 January 2019 (USA)'],
#        ['Battalion 609', 'tt9472208', nan, ...,
#         'Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elena Kazan|Vishwas Kini|Major Kishore|Jashn Kohli|Rammy C. Pandey|Manish Sharma|Sparsh Sharma|Farnaz Shetty|Vikas Shrivastav|Chandraprakash Thakur|Brajesh Tiwari|',
#         nan, '11 January 2019 (India)'],
#        ['The Accidental Prime Minister (film)', 'tt6986710',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/a/a1/The_Accidental_Prime_Minister_film.jpg/220px-The_Accidental_Prime_Minister_film.jpg',
#         ...,
# ...

# %%
X.head(10)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
# 6                         Fraud Saiyaan  tt5013008
# 7                            Bombairiya  tt4971258
# 8      Manikarnika: The Queen of Jhansi  tt6903440
# 9                      Thackeray (film)  tt7777196
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
X.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
X.isnull()
# Out:
#       title_x  imdb_id  poster_path  wiki_link  title_y  original_title  \
# 0       False    False        False      False    False           False
# 1       False    False         True      False    False           False
# 2       False    False        False      False    False           False
# 3       False    False        False      False    False           False
# 4       False    False         True      False    False           False
# ...       ...      ...          ...        ...      ...             ...
# 1624    False    False        False      False    False           False
# 1625    False    False        False      False    False           False
# 1626    False    False         True      False    False           False
# 1627    False    False        False      False    False           False
# 1628    False    False        False      False    False           False
#
#       is_adult  year_of_release  runtime  genres  imdb_rating  imdb_votes  \
# ...

# %%
X.sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
y= pd.read_csv("ipl-matches.csv")
y
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
y.shape
# Out:
# (950, 20)

# %%
y.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
y["TossDecision"]
# Out:
# 0        bat
# 1      field
# 2      field
# 3      field
# 4        bat
#        ...
# 945      bat
# 946      bat
# 947      bat
# 948      bat
# 949    field
# Name: TossDecision, Length: 950, dtype: object

# %%
y[["Venue","City"]]
# Out:
#                                           Venue        City
# 0              Narendra Modi Stadium, Ahmedabad   Ahmedabad
# 1              Narendra Modi Stadium, Ahmedabad   Ahmedabad
# 2                         Eden Gardens, Kolkata     Kolkata
# 3                         Eden Gardens, Kolkata     Kolkata
# 4                      Wankhede Stadium, Mumbai      Mumbai
# ..                                          ...         ...
# 945                                Eden Gardens     Kolkata
# 946                            Wankhede Stadium      Mumbai
# 947                            Feroz Shah Kotla       Delhi
# 948  Punjab Cricket Association Stadium, Mohali  Chandigarh
# 949                       M Chinnaswamy Stadium   Bangalore
#
# [950 rows x 2 columns]

# %%
type(y[["Venue","City"]])
# Out:
# pandas.core.frame.DataFrame

# %%
student = [
    [22,45,"harsh"],
    [22, 20,"vimal"],
    [30, 25,"om"],
    [23,45,"kaju"]
]
df1 = pd.DataFrame(student, columns=["age", "marks","name"]).set_index('name')

# %%
df1
# Out:
#        age  marks
# name
# harsh   22     45
# vimal   22     20
# om      30     25
# kaju    23     45

# %%
df2=pd.DataFrame({
    "marks":[50,55,53],
    "package":[5,7,3]
})
df2
# Out:
#    marks  package
# 0     50        5
# 1     55        7
# 2     53        3

# %%
df2.sum(axis=1)
# Out:
# 0    55
# 1    62
# 2    56
# dtype: int64

# %%
df2.sum()
# Out:
# marks      158
# package     15
# dtype: int64

# %%
df2.set_index("package")
# Out:
#          marks
# package
# 5           50
# 7           55
# 3           53

# %%
df2
# Out:
#    marks  package
# 0     50        5
# 1     55        7
# 2     53        3

# %%
df2.set_index("package",inplace= True)

# %%
df2
# Out:
#          marks
# package
# 5           50
# 7           55
# 3           53

# %%
df2.mean(axis=1)
# Out:
# package
# 5    50.0
# 7    55.0
# 3    53.0
# dtype: float64

# %%
df2.mean(axis=0)
# Out:
# marks    52.666667
# dtype: float64

# %%
y.iloc[0:3]  # used to select rows or for rows slicing and search using index(position)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# ...

# %%
X.iloc[5]
# Out:
# title_x                                                   Soni (film)
# imdb_id                                                     tt6078866
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link                   https://en.wikipedia.org/wiki/Soni_(film)
# title_y                                                          Soni
# original_title                                                   Soni
# is_adult                                                            0
# year_of_release                                                  2018
# runtime                                                            97
# genres                                                          Drama
# imdb_rating                                                       7.2
# imdb_votes                                                       1595
# story               Soni  a young policewoman in Delhi  and her su...
# ...

# %%
y.iloc[2:6:2]
# Out:
#         ID     City        Date Season MatchNumber  \
# 2  1312198  Kolkata  2022-05-25   2022  Eliminator
# 4  1304116   Mumbai  2022-05-22   2022          70
#
#                          Team1                 Team2  \
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                       Venue            TossWinner TossDecision SuperOver  \
# 2     Eden Gardens, Kolkata  Lucknow Super Giants        field         N
# 4  Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat         N
#
#                    WinningTeam    WonBy  Margin method Player_of_Match  \
# 2  Royal Challengers Bangalore     Runs    14.0    NaN      RM Patidar
# 4                 Punjab Kings  Wickets     5.0    NaN   Harpreet Brar
#
#                                         Team1Players  \
# 2  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 4  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
# ...

# %%
df1.loc["harsh"] #used to select rows or for rows slicing and search using name(position)
# Out:
# age      22
# marks    45
# Name: harsh, dtype: int64

# %%
df1.loc["harsh":"vimal"]
# Out:
#        age  marks
# name
# harsh   22     45
# vimal   22     20

# %%
X.iloc[1:6,0:3] # rows,columns
# Out:
#                                 title_x    imdb_id  \
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
#
#                                          poster_path
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
#finding final team and final winner of ipl

# %%
y["MatchNumber"]== "Final"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: MatchNumber, Length: 950, dtype: bool

# %%
df3= y[y["MatchNumber"]== "Final"]
df3
# Out:
#           ID          City        Date   Season MatchNumber  \
# 0    1312200     Ahmedabad  2022-05-29     2022       Final
# 74   1254117         Dubai  2021-10-15     2021       Final
# 134  1237181           NaN  2020-11-10  2020/21       Final
# 194  1181768     Hyderabad  2019-05-12     2019       Final
# 254  1136620        Mumbai  2018-05-27     2018       Final
# 314  1082650     Hyderabad  2017-05-21     2017       Final
# 373   981019     Bangalore  2016-05-29     2016       Final
# 433   829823       Kolkata  2015-05-24     2015       Final
# 492   734049     Bangalore  2014-06-01     2014       Final
# 552   598073       Kolkata  2013-05-26     2013       Final
# 628   548381       Chennai  2012-05-27     2012       Final
# 702   501271       Chennai  2011-05-28     2011       Final
# 775   419165        Mumbai  2010-04-25  2009/10       Final
# 835   392239  Johannesburg  2009-05-24     2009       Final
# 892   336040        Mumbai  2008-06-01  2007/08       Final
#
# ...

# %%
df3[["Season","WinningTeam","WonBy"]]
# Out:
#       Season            WinningTeam    WonBy
# 0       2022         Gujarat Titans  Wickets
# 74      2021    Chennai Super Kings     Runs
# 134  2020/21         Mumbai Indians  Wickets
# 194     2019         Mumbai Indians     Runs
# 254     2018    Chennai Super Kings  Wickets
# 314     2017         Mumbai Indians     Runs
# 373     2016    Sunrisers Hyderabad     Runs
# 433     2015         Mumbai Indians     Runs
# 492     2014  Kolkata Knight Riders  Wickets
# 552     2013         Mumbai Indians     Runs
# 628     2012  Kolkata Knight Riders  Wickets
# 702     2011    Chennai Super Kings     Runs
# 775  2009/10    Chennai Super Kings     Runs
# 835     2009        Deccan Chargers     Runs
# 892  2007/08       Rajasthan Royals  Wickets

# %%
y[y["SuperOver"]=="Y"]
# Out:
#           ID       City        Date   Season MatchNumber  \
# 114  1254077    Chennai  2021-04-25     2021          20
# 158  1216512  Abu Dhabi  2020-10-18  2020/21          35
# 159  1216517        NaN  2020-10-18  2020/21          36
# 184  1216547        NaN  2020-09-28  2020/21          10
# 192  1216493        NaN  2020-09-20  2020/21           2
# 203  1178426     Mumbai  2019-05-02     2019          51
# 244  1175365      Delhi  2019-03-30     2019          10
# 339  1082625     Rajkot  2017-04-29     2017          35
# 474   829741  Ahmedabad  2015-04-21     2015          18
# 533   729315  Abu Dhabi  2014-04-29     2014          19
# 608   598017  Bangalore  2013-04-16     2013          21
# 621   598004  Hyderabad  2013-04-07     2013           7
# 819   419121    Chennai  2010-03-21  2009/10          16
# 883   392190  Cape Town  2009-04-23     2009          10
#
#                            Team1                        Team2  \
# ...

# %%
y[y["SuperOver"]=="Y"].shape # how many super overs take place
# Out:
# (14, 20)

# %%
y[y["SuperOver"]=="Y"].shape[0]  # count only rows
# Out:
# 14

# %%
y[y["SuperOver"]== "Y"].shape[1]  #count only columns
# Out:
# 20

# %%
# how many matches csk won in kolkata

# %%
y[y["City"]=="Kolkata"]
# Out:
#           ID     City        Date   Season  MatchNumber  \
# 2    1312198  Kolkata  2022-05-25     2022   Eliminator
# 3    1312197  Kolkata  2022-05-24     2022  Qualifier 1
# 207  1178422  Kolkata  2019-04-28     2019           47
# 211  1178418  Kolkata  2019-04-25     2019           43
# 219  1178410  Kolkata  2019-04-19     2019           35
# ..       ...      ...         ...      ...          ...
# 908   336025  Kolkata  2008-05-18  2007/08           41
# 915   336017  Kolkata  2008-05-13  2007/08           35
# 922   336010  Kolkata  2008-05-08  2007/08           29
# 934   335997  Kolkata  2008-04-29  2007/08           16
# 945   335986  Kolkata  2008-04-20  2007/08            4
#
#                            Team1                        Team2  \
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 207        Kolkata Knight Riders               Mumbai Indians
# ...

# %%
y[(y["City"]=="Kolkata") & (y['WinningTeam']=='Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
y[y['TossWinner']==y['WinningTeam']]
# Out:
#           ID         City        Date   Season  MatchNumber  \
# 1    1312199    Ahmedabad  2022-05-27     2022  Qualifier 2
# 3    1312197      Kolkata  2022-05-24     2022  Qualifier 1
# 5    1304115       Mumbai  2022-05-21     2022           69
# 8    1304112  Navi Mumbai  2022-05-18     2022           66
# 11   1304109       Mumbai  2022-05-15     2022           63
# ..       ...          ...         ...      ...          ...
# 935   335996    Bangalore  2008-04-28  2007/08           15
# 937   335994       Mumbai  2008-04-27  2007/08           14
# 939   335992    Bangalore  2008-04-26  2007/08           12
# 941   335990    Hyderabad  2008-04-24  2007/08            9
# 948   335983   Chandigarh  2008-04-19  2007/08            2
#
#                            Team1                  Team2  \
# 1    Royal Challengers Bangalore       Rajasthan Royals
# 3               Rajasthan Royals         Gujarat Titans
# 5                 Delhi Capitals         Mumbai Indians
# ...

# %%
y[y['TossWinner']==y['WinningTeam']].shape
# Out:
# (489, 20)

# %%
(y[y['TossWinner']==y['WinningTeam']].shape[0]/y.shape[0])*100 # probablity that toss winner is match winner
# Out:
# 51.473684210526315

# %%
#movies that have rating greater than 8 and vote greater than  1000

# %%
X.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
X[(X["imdb_rating"]>8) & (X["imdb_votes"]>1000)]
# Out:
#                           title_x     imdb_id  \
# 0        Uri: The Surgical Strike   tt8291224
# 11                      Gully Boy   tt2395469
# 37              Article 15 (film)  tt10324144
# 40                Super 30 (film)   tt7485048
# 53                    Section 375   tt8144834
# 58              Ghost (2019 film)   tt9378950
# 59               Bala (2019 film)   tt9420648
# 62                 Saand Ki Aankh   tt8108206
# 64                    Ujda Chaman  tt11046300
# 84                      Mukkabaaz   tt7180544
# 143                       Tumbbad   tt8239946
# 146                     Andhadhun   tt8108198
# 192      Sachin: A Billion Dreams   tt4640206
# 279            Nil Battey Sannata   tt5005684
# 325              Pink (2016 film)   tt5571734
# 354                 Dangal (film)   tt5074352
# 418                        Masaan   tt4635372
# 426          Drishyam (2015 film)   tt4430212
# 436                 Talvar (film)   tt4934950
# ...

# %%
X[(X["imdb_rating"]>8) & (X["imdb_votes"]>1000)].shape # count only no. of rows and columns
# Out:
# (53, 18)

# %%
# toss decisions in ipl

# %%
y["TossDecision"].value_counts()
# Out:
# field    599
# bat      351
# Name: TossDecision, dtype: int64

# %%
y["TossDecision"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
y["TossDecision"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='TossDecision'>

# %%
# how many matches each team had played

# %%
y["Team1"].value_counts()
# Out:
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: Team1, dtype: int64

# %%
y["Team2"].value_counts()
# Out:
# Mumbai Indians                 119
# Kolkata Knight Riders          118
# Rajasthan Royals               103
# Royal Challengers Bangalore    100
# Kings XI Punjab                 98
# Chennai Super Kings             97
# Sunrisers Hyderabad             83
# Delhi Daredevils                76
# Deccan Chargers                 36
# Delhi Capitals                  34
# Pune Warriors                   23
# Gujarat Lions                   14
# Punjab Kings                    10
# Gujarat Titans                   9
# Rising Pune Supergiant           9
# Rising Pune Supergiants          7
# Lucknow Super Giants             7
# Kochi Tuskers Kerala             7
# Name: Team2, dtype: int64

# %%
(y["Team1"].value_counts()+y["Team2"].value_counts()).sort_values()
# Out:
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Lucknow Super Giants            15
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Punjab Kings                    28
# Gujarat Lions                   30
# Pune Warriors                   46
# Delhi Capitals                  63
# Deccan Chargers                 75
# Sunrisers Hyderabad            152
# Delhi Daredevils               161
# Kings XI Punjab                190
# Rajasthan Royals               192
# Chennai Super Kings            208
# Kolkata Knight Riders          223
# Royal Challengers Bangalore    226
# Mumbai Indians                 231
# dtype: int64

# %%
# add new columns in data

# %%
X["country"]= "India"
X                         # if want to make permanent change than write .inplace= True
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...
