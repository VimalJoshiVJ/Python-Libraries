# %%
import pandas as pd

# %%
df=pd.read_excel("C:\\Users\\avnis\\OneDrive\\Pictures\\Camera Roll\\Documents\\friends.csv.xlsx")

# %%
df
# Out:
#    0      NAME  MARKS         CITY  CLASS
# 0  1  priyanka     34  pithoragarh      9
# 1  2    preeti     45     dehradun      8
# 2  3    himani     34     tanakput      7
# 3  4     kajal     45    champawat      6
# 4  5    nikita     45     tawaghat      5

# %%
d=pd.read_excel("C:\\Users\\avnis\\Downloads\\INTERNAL MARKS BREAK UP AY21-24 2nd sem.xlsx")

# %%
d
# Out:
#    B.Voc.BANKING AND FINANCIAL MANAGEMENT AY(2021-24)\nINTERNAL ASSESSMENT I  2ND SEMESTER  \
# 0                                              SR NO.
# 1                                                 NaN
# 2                                                 NaN
# 3                                             SBFM001
# 4                                             SBFM002
# 5                                             SBFM003
# 6                                             SBFM004
# 7                                             SBFM005
# 8                                             SBFM006
# 9                                             SBFM007
# 10                                            SBFM008
# 11                                            SBFM009
# 12                                            SBFM010
# 13                                            SBFM011
# 14                                                NaN
# 15                                                NaN
# ...

# %%
d.columns
# Out:
# Index(['B.Voc.BANKING AND FINANCIAL MANAGEMENT AY(2021-24)\nINTERNAL ASSESSMENT I  2ND SEMESTER',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'],
#       dtype='object')

# %%
d['B.Voc.BANKING AND FINANCIAL MANAGEMENT AY(2021-24)\nINTERNAL ASSESSMENT I  2ND SEMESTER']
# Out:
# 0      SR NO.
# 1         NaN
# 2         NaN
# 3     SBFM001
# 4     SBFM002
# 5     SBFM003
# 6     SBFM004
# 7     SBFM005
# 8     SBFM006
# 9     SBFM007
# 10    SBFM008
# 11    SBFM009
# 12    SBFM010
# 13    SBFM011
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# 30        NaN
# 31        NaN
# 32        NaN
# 33    SR. NO.
# 34        NaN
# 35        NaN
# 36        NaN
# 37    SNHS001
# 38    SNHS002
# 39    SNHS003
# 40    SNHS004
# 41    SNHS005
# 42    SNHS006
# Name: B.Voc.BANKING AND FINANCIAL MANAGEMENT AY(2021-24)\nINTERNAL ASSESSMENT I  2ND SEMESTER, dtype: object

# %%
s=d['B.Voc.BANKING AND FINANCIAL MANAGEMENT AY(2021-24)\nINTERNAL ASSESSMENT I  2ND SEMESTER']

# %%
s
# Out:
# 0      SR NO.
# 1         NaN
# 2         NaN
# 3     SBFM001
# 4     SBFM002
# 5     SBFM003
# 6     SBFM004
# 7     SBFM005
# 8     SBFM006
# 9     SBFM007
# 10    SBFM008
# 11    SBFM009
# 12    SBFM010
# 13    SBFM011
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# 30        NaN
# 31        NaN
# 32        NaN
# 33    SR. NO.
# 34        NaN
# 35        NaN
# 36        NaN
# 37    SNHS001
# 38    SNHS002
# 39    SNHS003
# 40    SNHS004
# 41    SNHS005
# 42    SNHS006
# Name: B.Voc.BANKING AND FINANCIAL MANAGEMENT AY(2021-24)\nINTERNAL ASSESSMENT I  2ND SEMESTER, dtype: object

# %%
len(s)
# Out:
# 43

# %%
s=d['B.Voc.BANKING AND FINANCIAL MANAGEMENT AY(2021-24)\nINTERNAL ASSESSMENT I  2ND SEMESTER'][0:10]

# %%
s
# Out:
# 0     SR NO.
# 1        NaN
# 2        NaN
# 3    SBFM001
# 4    SBFM002
# 5    SBFM003
# 6    SBFM004
# 7    SBFM005
# 8    SBFM006
# 9    SBFM007
# Name: B.Voc.BANKING AND FINANCIAL MANAGEMENT AY(2021-24)\nINTERNAL ASSESSMENT I  2ND SEMESTER, dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
l=['a','b','c','d','e','f','g','h','r','g']

# %%
pd.Series(s,index=l)
# Out:
# a    NaN
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# f    NaN
# g    NaN
# h    NaN
# r    NaN
# g    NaN
# Name: B.Voc.BANKING AND FINANCIAL MANAGEMENT AY(2021-24)\nINTERNAL ASSESSMENT I  2ND SEMESTER, dtype: object

# %%
pd.Series(list(s),index=l)
# Out:
# a     SR NO.
# b        NaN
# c        NaN
# d    SBFM001
# e    SBFM002
# f    SBFM003
# g    SBFM004
# h    SBFM005
# r    SBFM006
# g    SBFM007
# dtype: object

# %%
s1=pd.Series(list(s),index=l)

# %%
s1
# Out:
# a     SR NO.
# b        NaN
# c        NaN
# d    SBFM001
# e    SBFM002
# f    SBFM003
# g    SBFM004
# h    SBFM005
# r    SBFM006
# g    SBFM007
# dtype: object

# %%
s2=s1.append(s)
# Out:
# C:\Users\avnis\AppData\Local\Temp\ipykernel_17144\2552242485.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s2=s1.append(s)

# %%
s2[0]
# Out:
# 'SR NO.'

# %%
s2[4]
# Out:
# 'SBFM002'

# %%
s3=pd.Series([3,4,5,6,6,],index[2,3,4,5,6])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 s3=pd.Series([3,4,5,6,6,],index[2,3,4,5,6])
#
# NameError: name 'index' is not defined
